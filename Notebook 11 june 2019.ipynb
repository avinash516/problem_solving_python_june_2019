# %% [markdown]
# # Notebook Basics

# %% [markdown]
# ### MArkDOWN
# * **Bold **<br>
# * *italic*<br>
# * ***IB***<br>
# * **prasanna **
#   * raj
#   * sri
#     * nivas
#
#
# 1. Ordered List element1
# 2. Ordered List element2
#
#
# ![Jupyter Logo](Jupyter_logo.png)
#
# - [x] opt1
# - [x] opt2
#
# <img src="Jupyter_logo.png" style="float:left">

# %% [markdown]
# ## Python Basics
# ### Version 3.7
# - scripting
# - object oriented
# - functinol

# %%
# python comments
print("good afternoon",end=" ")#basic concepts
print("Hello python")
# Out:
# good afternoon Hello python

# %% [markdown]
# ## Assignment

# %%
n1 = 123456
n2=n3=n4=n1
n3
a,b,c=1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %% [markdown]
# # DataTypes
# - int
# - float
# - string
# - double

# %% [markdown]
# ## Arthemetic Operations
# - +
# - -
# - *
# - /
# - %
# - **

# %%
n1 % 11

n3=n2 ** 12345
#len(str(n3))
n3
# Out:
# ...

# %% [markdown]
# # Conditional Checking

# %%
atom=10 ** 20
atom < 10 ** 9
# Out:
# False

# %%
type(a)
s1 = "python"
type(s1)
f1 = 12.345
type(f1)
#f1
# Out:
# 12.345

# %%
if atom < 10 ** 9:
    print("True")
else:
    print("False")
# Out:
# False

# %%
#check if a number is Even

n = 123
if n % 2 == 0:
    print("even number")
else:
    print("odd number")
# Out:
# odd number

# %% [markdown]
# ## find the greatest of 3 number
#
# n1 = input("enter 1st num:")
# n2 = input("enter 2st num:")
# n3 = input("enter 3st num:")
#
# if n1 > n2 and n1> n3:
#     print(n1, "is the greatest number")
# elif n2 > n3:
#     print(n2 , "is the greatest number")
# else:
#     print(n3, "is the greatest number")

# %%
n1 = int(input("enter 1st num:"))
n2 = int(input("enter 2st num:"))
n3 = int(input("enter 3st num:"))

if n1 > n2 and n1> n3:
    print(n1, "is the greatest number")
elif n2 > n3:
    print(n2 , "is the greatest number")
else:
    print(n3, "is the greatest number")
# Out:
# enter 1st num:-55
# enter 2st num:23
# enter 3st num:-77
# 23 is the greatest number

# %%
# leap year
year = int(input("enter a year"))
if(year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)):
    print("leap year")
else:
    print("not leap year")
# Out:
# enter a year2000
# leap year

# %%
# check if a number exists in a given number range(inclusive)
n1 =int(input("enter number"))
lb =int(input("enter lb number"))
ub =int(input("enter ub number"))
if n1 in range(lb,ub):
    print("yes")
else:
    print("no")
# Out:
# enter number6
# enter lb number3
# enter ub number14
# yes

# %%
# calculate the number of digits in a number


n = input("enter a  number:")
count = 0
for i in n:
    if i.isdigit():
        count=count+1
print(count)

#l = 12345
#print(len(l))
# Out:
# enter a  number:343ghghgf746736
# 9

# %%
# chek if a number is multiple of 10
l = 10
if l % 10 == 0:
    print()

# %%
# check if a number is a factor of 1000
n1 = 100
if 1000 % n1 ==0:
    print(n1,"is a factor of 1000")
else:
    print("not a factor")
# Out:
# 100 is a factor of 1000

# %%
# check if given string is equal to a number
s = "python"
n = 12345
if s == str(n):
    print("equal")
else:
    print("not equal")
# Out:
# not equal

# %%
# calculate the square root of a number without any functions
n=456
n ** 0.5
# Out:
# 21.354156504062622

# %%
# calculate the number of nano seconds in a given year(considering leap year logic)
year = 2019
if(year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)):
    print(366 * 24 * 60 * 60 * (10 ** 9) )
else:
    print(366 * 24 * 60 * 60 * (10 ** 9))
# Out:
# 31622400000000000
